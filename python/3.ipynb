# %%
print("hrllo")
# Out:
# hrllo

# %%
a = [1,2,3,4,5,4,3]

print(a)
# Out:
# [1, 2, 3, 4, 5, 4, 3]

# %%
b = ( 1,3,4,)
print(b)
# Out:
# (1, 3, 4)

# %%
c = "hardik"
print(type(c))
# Out:
# <class 'str'>

# %%
d = {"raj","taj0" , "laj"}
print(type(d))
# Out:
# <class 'set'>

# %%
e = {key:}

# %%
a=[31,43,4,231,343,34]
del a[1:5]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [31, 34]

# %%
a=[31,43,4,231,343,34]
a.clear()
print(type(a))
print(a)
# Out:
# <class 'list'>
# []

# %%
a={
    'ac':'hyy',
    'aod':'jg',
    'hc':'gh'
}
print(a.popitem())
print(a)
print(a.pop('ac'))
print(a)
# Out:
# ('hc', 'gh')
# {'ac': 'hyy', 'aod': 'jg'}
# hyy
# {'aod': 'jg'}
